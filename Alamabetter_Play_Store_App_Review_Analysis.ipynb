# %% [markdown]
# <a href="https://colab.research.google.com/github/sharath199324/almabetter_projects/blob/main/Alamabetter_Play_Store_App_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** sharath kumar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Comprehensive Analysis of Google Play Store Apps**
#
# **Importing Libraries:**
# Our data science journey commenced with the essential step of importing libraries to facilitate seamless data analysis. Libraries such as pandas, numpy, and matplotlib were instrumental in handling and visualizing the dataset.
#
# **Getting the Dataset:**
# The focal point of our project was the Google Play Store, a cornerstone of the Android ecosystem. Two datasets were acquired—one containing comprehensive information about various apps and another encompassing customer reviews. These datasets laid the foundation for our exploration into the Android app market.
#
# **Importing Datasets:**
# With the datasets in hand, we proceeded to import them into our environment. Leveraging pandas, we organized the data for effective analysis, aiming to uncover valuable insights.
#
# **Reading the Data:**
# Understanding the structure and content of our datasets was crucial. We utilized pandas' capabilities to read the data, gaining insights into the variables and their potential impact on our analysis.
#
# **Finding Missing Data:**
# A critical aspect of data preparation involves identifying and addressing missing data. Thorough exploration and analysis were conducted to ensure the integrity of our findings. Missing values, if any, were handled strategically to prevent bias in our results.
#
# **Data Cleaning:**
# Ensuring the quality of our data was paramount. Data cleaning activities, including addressing duplicates, handling outliers, and refining variable formats, were undertaken to enhance the reliability of our analysis. This step laid the groundwork for accurate and meaningful visualizations.
#
# **Data Visualization:**
# The heart of our project was the exploration and visualization of data. Through various charts and graphs, we brought the Android app market to life, highlighting trends, patterns, and correlations. Visualizations included average ratings, app categories, pricing trends, and user engagement metrics. These visualizations not only made the data digestible but also provided a foundation for actionable business insights.
#
# **Conclusion:**
# Our analysis uncovered fascinating trends and insights within the Google Play Store ecosystem. The average rating of active apps stood at a commendable 4.17, reflecting a positive user sentiment. Notably, communication apps like Facebook and WhatsApp garnered high reviews, underscoring their widespread user engagement.
#
# Medical and Family apps emerged as the most expensive, with prices reaching up to $80. User preferences aligned with reviews and downloads, indicating that a substantial number of reviews correlated with higher downloads. Categories such as Family, Sports, and Health & Fitness received predominantly positive ratings, while games and social media apps exhibited a more balanced mix of positive and negative reviews.
#
# The conclusion drawn from our findings suggested that the Android market is currently dominated by apps from categories like GAME, COMMUNICATION, and TOOL. Despite the Family category having twice as many apps, it is the former categories that attract the most user attention. This trend emphasizes a focus on quality rather than quantity among developers in these categories.
#
# Furthermore, our visualizations demonstrated that highly-rated apps generally receive a significant number of reviews and installs. The size and price of an app did not necessarily correlate with high ratings, debunking any preconceived notions about the relationship between these factors.
#
# In summary, our project shed light on the current trends in the Android market, showcasing the dominance of categories that either assist, communicate, or entertain users. The top categories, such as GAME, SOCIAL, COMMUNICATION, and TOOL, dictated the Android landscape, with a focus on quality and user engagement rather than sheer volume of apps.
#
# Through robust data analysis and visualization, our project not only provided valuable insights for developers but also contributed to a deeper understanding of the evolving dynamics within the Android app market.

# %% [markdown]
# # GitHub Link -

# %% [markdown]
# https://github.com/sharath199324/almabetter_projects/blob/main/Alamabetter_Play_Store_App_Review_Analysis.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Today, Android stands as the predominant mobile operating system, powering approximately 85% of all mobile devices. The Google Play Store, the largest and most widely used Android app marketplace, is integral to this dominance.
# Our project aimed to collect and analyze comprehensive information about apps available on the Google Play Store, intending to offer insights into app features and the current state of the Android app market.
# The data from the Play Store apps holds immense potential to propel app-centric businesses toward success, providing actionable insights for developers to focus on and capture the Android market.
# Each app entry includes values for categories, ratings, sizes, and more. Another dataset encompasses customer reviews of Android apps.
#
# Delve into the data to explore and analyze factors crucial for app engagement and success.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Explore and analyze the data to discover key factors responsible for app engagement and success.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib import rcParams

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Here we just read the data frame
df1=pd.read_csv('/content/drive/MyDrive/project files/alternative/Play Store Data.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df1.shape
# Out:
# (10841, 13)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df1.duplicated().sum()
# Out:
# 483

# %%
print(f'we have {df1.duplicated().sum()} duplicate values in dataset')
# Out:
# we have 483 duplicate values in dataset

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df1.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize = (15,5))
sns.heatmap(df1.isnull(),cmap='plasma',annot=False,yticklabels=False)
plt.title(" Visualising Missing Values")
# Out:
# Text(0.5, 1.0, ' Visualising Missing Values')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Upon inspecting the data frame, we observe the following:
#
# The dataset comprises 13 columns, encompassing 10841 rows of information.
#
# With 1474 null values in ratings column, 1 in type, 1 in content rating, 8 in current ver, and 3 in android ver.
#
# Columns such as 'Reviews', 'Size', 'Installs', and 'Price' are categorized as 'object' data types.
#
# In the 'Size' column, the values are expressed as strings denoting size in 'M' for Megabytes, 'k' for kilobytes, and also 'Varies with devices'.
#
# The 'Installs' column contains string representations of installation amounts, including symbols such as '+'.
#
# Similarly, the 'Price' column holds string representations of prices, with the symbol '$'.
#
# Consequently, it is evident that some data cleaning is necessary.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Describe
df1.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# App: The app's name as listed on the Play Store
#
# Category: The app's designated category on the Play Store
#
# Rating: The app's rating on the Play Store
#
# Reviews: The total number of reviews for the app
#
# Size: The app's file size
#
# Install: The number of installations for the app
#
# Type: The app's classification (Free/Paid)
#
# The app's price (0 if it is free)
#
# Content Rating: The intended target audience for the app
#
# Genres: The app's genre
#
# Last Updated: The date of the app's last update
#
# Current Ver: The present version of the app
#
# Android Ver: The minimum required Android version to run the app

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
column_values = df1.columns.to_list()
for i in column_values :
  print('unique values in', i, 'are : ',df1[i].unique())
# Out:
# unique values in App are :  ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Parkinson Exercices FR' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']
# unique values in Category are :  ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']
# unique values in Rating are :  [ 4.1  3.9  4.7  4.5  4.3  4.4  3.8  4.2  4.6  3.2  4.   nan  4.8  4.9
#   3.6  3.7  3.3  3.4  3.5  3.1  5.   2.6  3.   1.9  2.5  2.8  2.7  1.
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#Convert install coloum string to int in install price and review

def convert_int(x) :
  if isinstance(x, int):
    return x
  x = str(x)
  x = x.replace(',','')
  x = x.replace('+', '')
  x = x.replace('M', '')
  x = x.replace('k', '')
  x = x.replace('$', '')
  if x == 'Free' or x == 'Varies with device' or x == 'Everyone':
    return 0
  else:
    return int(float(x))

# %%
#Converting installs,price,reviews to int value for better calculations
df1['Installs']=df1['Installs'].apply(convert_int)
df1['Size_int']=df1['Size'].apply(convert_int)
df1['Price']=df1['Price'].apply(convert_int)
df1['Reviews']=df1['Reviews'].apply(convert_int)

# %%
#convert size due to size divided into multiple category so we convert into to same format(mb=1024k, k=mb/1024)
def convert_int2(x):
    x=x.lower()

    if x=='varies with device':
        x=0
    else:
        if 'm' in x:
            x=x.replace('m','')
            x=eval(x)
        elif 'k' in x :
            x=x.replace('k','')
            x=eval(x)/1024
        else:
            x=-100

    return x
df1['Size_int']=df1['Size'].apply(convert_int2)

# %%
# adjusting those app ratings which are  more than 5.
#rating_more_5 = df1[df1['Rating'] >5].index
rating_median = df1['Rating'].median()
df1.loc[df1['Rating']>5,'Rating'] = rating_median

# %%
df1['Rating']=df1['Rating'].fillna(rating_median)
df1.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# Size_int          0
# dtype: int64

# %%
#Removing the app which contains no type

type_null_index=df1[df1['Type'].isna()].index
df1=df1.drop(index=type_null_index)
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# Size_int          0
# dtype: int64

# %%
df1 = df1.drop_duplicates(subset=['App'])
df1.shape
# Out:
# (9659, 14)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Prepared the following columns [ install, size, price, review,rating ] as numeric type for further analysis.
#
# replaced the null values of rating column with its median.
#
# Droped the row where the column -'type' was null.
#
# And removed the duplicate rows.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
sns.set_style('darkgrid')
plt.figure(figsize=(10, 5))
sns.countplot(x='Category', data=df1)
plt.title('Number of Apps Per Category')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the number of apps for each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can see that there are highest no. of app from family category and at second there is game.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes.It will help to gain insight to help creating a positive business impact.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
users=df1.groupby(['Category'])['Installs'].sum().reset_index()
sns.set_style('darkgrid')
plt.figure(figsize=(10, 5))
sns.barplot(x='Category',y='Installs',data=users)
plt.title('Number of install Apps per Category')
plt.xticks(rotation=90)
plt.ylabel('Number of User')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the highest no. of user/installed app category wise.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As for the above graph we conclude that most users are showing interest in Gaming apps and after gaming, people are shoing their interest in communication apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes.It will help to gain insight to help creating a positive business impact.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(10, 5))
sns.countplot(x='Rating', data=df1)
plt.title('Rating Distribution')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the distribution of rating.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this distribution plotting, it implies that most of the apps in the Play Store are having rating higher than 4 or in the range of 4 to 4.7.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes.It will help to gain insight to help creating a positive business impact.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(14,9))

val = sns.boxplot(data=df1, x="Category", y="Rating")
val.axhline(df1['Rating'].mean(),ls="-",color="red")
x=plt.xticks(rotation=90)
print('Avg rating:-',df1['Rating'].mean())
# Out:
# Avg rating:- 4.1924422818097105

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we compared the app category wise with rating (which category get more rating with avg. and which gets low)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Red Line is the Average of rating
#
# Performance of all app categories is mostly decent. Highest quality apps with 50% apps with a rating higher than 4.5 are Health and Fitness and Book and Reference app. This is considered to be extremely high!
#
# However, the apps in Dating category having lower rating than the average ratings is 50%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,the game category has app more app rated as compared to avg and from Health and Fitness almost all app rated more than avg this is consider as positive feedback of those category.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# Reviews Per Rating
rating=df1.groupby(['Rating']).sum().reset_index()
plt.figure(figsize=(8, 4))
plt.plot(rating['Rating'], rating['Reviews'])
plt.xlabel('Rating')
plt.ylabel('Reviews')
plt.title('Reviews Per Rating')
plt.show()
# Out:
# <ipython-input-17-5a387a6265af>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   rating=df1.groupby(['Rating']).sum().reset_index()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the corelatation between how rating affected reviews

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graphs, we see most of the apps whose rating range is in between 4.0 - 4.7 are having high amount of reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, customers tend to favour those apps more whose rating range is in between 4.0 - 4.7

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# Size Per Rating
plt.figure(figsize=(8, 4))
plt.plot(rating['Rating'], rating['Size_int'])
plt.xlabel('Rating')
plt.ylabel('Size')
plt.title('Size Per Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the corelatation between how rating affected size

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graphs, we see most of the apps whose rating range is in between 4.0 - 4.7 are having high size.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, customers tend to favour those apps more whose rating range is in between 4.0 - 4.7

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# Installs Per Rating
plt.figure(figsize=(8, 4))
plt.plot(rating['Rating'], rating['Installs'])
plt.xlabel('Rating')
plt.ylabel('Installs')
plt.title('Installs Per Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the corelatation between how rating affected installs

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graphs,we see most of the apps whose rating range is in between 4.0 - 4.7 are having high installs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, customers tend to install those app which get highest no. of reviews.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# Price Per Rating
plt.figure(figsize=(8, 4))
plt.plot(rating['Rating'], rating['Price'])
plt.xlabel('Rating')
plt.ylabel('Price')
plt.title('Price Per Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the corelatation between how rating affected price

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graphs, we see in terms of price, it doesn't reflect a direct relationship with rating, as we could see a fluctuation in term of pricing even at the range of high rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# no

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
fig, ax = plt.subplots(figsize=(7, 7), subplot_kw=dict(aspect="equal"))

number_of_apps = df1['Type'].value_counts()

labels = number_of_apps.index
sizes = number_of_apps.values

ax.pie(sizes,labeldistance=2,autopct='%1.1f%%')
ax.legend(labels=labels,loc="right",bbox_to_anchor=(0.9, 0, 0.5, 1))
ax.axis("equal")
plt.title('Type Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We want to count a paricular column comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the plot we can imply that majority of the apps in the Play Store are Free apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Not much, because most of the apps are free apps.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
fig, ax = plt.subplots(figsize=(7, 7), subplot_kw=dict(aspect="equal"))

number_of_apps = df1['Content Rating'].value_counts()

labels = number_of_apps.index
sizes = number_of_apps.values

ax.pie(sizes,labeldistance=2,autopct='%1.1f%%')
ax.legend(labels=labels,loc="right",bbox_to_anchor=(0.9, 0, 0.5, 1))
ax.axis("equal")
plt.title('Content Distributation')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we just want to see diffent type of content present in playstore

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see most of content available for Everyone.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Not much because type of content does not really affect the growth of the app.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
fig, axes = plt.subplots(figsize=(8, 8))
sns.heatmap(df1.corr(), ax=axes, annot=True, linewidths=0.1, fmt='.2f', square=True)
plt.show()
# Out:
# <ipython-input-66-216b2e017a75>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(), ax=axes, annot=True, linewidths=0.1, fmt='.2f', square=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Want to see the corelation with each category to other category by using heat map.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Installs and review are highly corelated to each other.
#
# A moderate positive correlation of 0.63 exists between the number of reviews and number of installs. This means that customers tend to download a given app more if it has been reviewed by a larger number of people.
#
# This also means that many active users who download an app usually also leave back a review or feedback.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,getting your app reviewed by more people maybe a good idea to increase your app's capture in the market!

# %% [markdown]
# # Sentiment Analysis (2nd DataSet)

# %% [markdown]
# This document presents the outcome of sentiment analysis performed by the creator of the dataset. It encompasses 64,295 rows of data featuring the following attributes:
#
# App: The name of the application.
#
# ---
#
#
# Translated_Review: Either the original review in English or a translated version if the original review is in a different language.
#
#
# ---
#
#
# Sentiment: The result of sentiment analysis conducted on a review, categorized as Positive, Neutral, or Negative.
#
#
# ---
#
#
# Sentiment_Polarity: A numerical value indicating the positivity or negativity of the sentiment, ranging from -1 (most negative) to 1 (most positive).
#
#
# ---
#
#
# Sentiment_Subjectivity: A value ranging from 0 to 1, reflecting the subjectivity of the review. Lower values suggest the review is grounded in factual information, while higher values indicate the review is influenced by personal or public opinions and judgments.

# %%
# reading and checking information of Second dataset
df2=pd.read_csv('/content/drive/MyDrive/project files/alternative/User Reviews.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
# dropping all the null values
df2.dropna(inplace=True)

# %%
#Here we are merging our play store data set and review data set
df3=pd.merge(df1,df2,how='inner',on='App')

# %%
# checking basic info and displaying the first few rows

df3.head()
# Out:
#                    App        Category  Rating  Reviews Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9      967  14M    500000  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9      967  14M    500000  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9      967  14M    500000  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9      967  14M    500000  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9      967  14M    500000  Free
#
#    Price Content Rating                     Genres      Last Updated  \
# 0      0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1      0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2      0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3      0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4      0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  Size_int  \
# 0       2.0.0  4.0.3 and up      14.0
# ...

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
#Sentiment Analysis on different Category basis

plt.figure(figsize=(15,8))
sns.histplot(
    data=df3,
    x="Category", hue="Sentiment", multiple="stack"
    )

plt.title("Sentiment Analysis Based on Category")
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see which category of app performs best.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Family, Sports and Health & Fitness apps perform the best, Having more than 50% positive reviews and Game and Social apps perform decent leading to 50% positive and 50% negative.
#
# The no. of review of game is much more higher in compare to other.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it will help which category of app will perform good.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
plt.figure(figsize=(15,8))
sns.histplot(
    data=df3,
    x="Sentiment_Subjectivity"
    )

plt.title("")
plt.xticks(rotation='vertical')
plt.axvline(df3['Sentiment_Subjectivity'].mean(), color='g', linestyle='dashed', linewidth=2)
plt.axvline(df3['Sentiment_Subjectivity'].median(), color='red', linestyle='dashed', linewidth=2)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram along with the KDE line lets us visualize the density & the distribution of the feature. The mean & median dashed lines also gives us the level of skewness.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can see the data is centered.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it will help in feature manipulations.

# %% [markdown]
# #### Chart - 14

# %%
# Chart - 14 visualization code
plt.figure(figsize=(15,8))
sns.histplot(
    data=df3,
    x="Sentiment_Polarity"
    )

plt.title("")
plt.xticks(rotation='vertical')
plt.axvline(df3['Sentiment_Polarity'].mean(), color='g', linestyle='dashed', linewidth=2)
plt.axvline(df3['Sentiment_Polarity'].median(), color='red', linestyle='dashed', linewidth=2)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram along with the KDE line lets us visualize the density & the distribution of the feature. The mean & median dashed lines also gives us the level of skewness.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can see the data is sightly left skewed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it will help in feature manipulations.

# %% [markdown]
# #### Chart - 15

# %%
# Pair Plot visualization code
sns.pairplot(df3, corner=True)

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# ###Average rating of (active) apps on Google Play Store is 4.17.
#
# ### If we see individually app wise the communicatation app like facebook and whatsapp get highly reviewed app it shown that people regulary active on that and give there feedback also on that.
#
# ###Medical and Family apps are the most expensive and even extend upto 80$.
#
# ###Users tend to download a given app more if it has been reviewed by a large number of people.
#
# ###More than half users rate Family, Sports and Health & Fitness apps positively. Apps for games and social media get mixed reviews, with 50 percent positive and 50 percent negative responses.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ### The Google Play Store Apps report provides some useful details regarding the trending of the apps in the play store. As per the graphs visualizations shown above, most of the trending apps (in terms of users' installs) are from the categories like GAME, COMMUNICATION, and TOOL even though the amount of available apps from these categories are twice as much lesser than the category FAMILY but still used most. The trending of these apps are most probably due to their nature of being able to entertain or assist the user. Besides, it also shows a good trend where we can see that developers from these categories are focusing on the quality instead of the quantity of the apps.
#
# ### Other than that, the charts shown above actually implies that most of the apps having good ratings of above 4.0 are mostly confirmed to have high amount of reviews and user installs. The size and price shouldn't reflect that apps with high rating are mostly big in size and pricy as by looking at the graphs they are most probably are due to some minority. Futhermore, most of the apps that are having high amount of reviews are from the categories of SOCIAL, COMMUNICATION and GAME like Facebook, WhatsApp Messenger, Instagram, Messenger – Text and Video Chat for Free, Clash of Clans ,google apps etc.
#
# ### Eventhough apps from the categories like GAME, SOCIAL, COMMUNICATION and TOOL of having the highest amount of installs, rating and reviews are reflecting the current trend of Android users, they are not even appearing as category in the top 5 most expensive apps in the store . As a conclsuion, we learnt that the current trend in the Android market are mostly from these categories which either assisting, communicating or entertaining apps.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
